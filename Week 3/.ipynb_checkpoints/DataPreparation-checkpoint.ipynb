# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('PD 2023 Wk 1 Input.csv')
targets = pd.read_csv('Targets.csv')

# %%
df.head()
# Out:
#   Transaction Code  Value  Customer Code  Online or In-Person  \
# 0  DTB-716-679-576   1448         100001                    2
# 1   DS-795-814-303   7839         100001                    2
# 2  DSB-807-592-406   5520         100005                    1
# 3   DS-367-545-264   7957         100007                    2
# 4  DSB-474-374-857   5375         100000                    2
#
#       Transaction Date
# 0  20/03/2023 00:00:00
# 1  15/11/2023 00:00:00
# 2  14/07/2023 00:00:00
# 3  18/08/2023 00:00:00
# 4  26/08/2023 00:00:00

# %%
targets.head()
# Out:
#   Online or In-Person     Q1     Q2     Q3     Q4
# 0              Online  72500  70000  60000  60000
# 1           In-Person  75000  70000  70000  60000

# %%
df[df['Transaction Code'].apply(lambda x: x.startswith('DSB'))]
# Out:
#     Transaction Code  Value  Customer Code  Online or In-Person  \
# 2    DSB-807-592-406   5520         100005                    1
# 4    DSB-474-374-857   5375         100000                    2
# 5    DSB-448-546-348   4525         100009                    1
# 11   DSB-422-218-322    118         100010                    1
# 12   DSB-669-227-170    830         100001                    1
# ..               ...    ...            ...                  ...
# 350  DSB-618-298-395   9280         100008                    1
# 351  DSB-637-369-281   6060         100002                    2
# 353  DSB-322-596-206    900         100001                    1
# 354  DSB-384-247-358   6446         100003                    1
# 359  DSB-879-328-611   8316         100008                    1
#
#         Transaction Date
# 2    14/07/2023 00:00:00
# 4    26/08/2023 00:00:00
# 5    27/05/2023 00:00:00
# 11   12/05/2023 00:00:00
# 12   15/04/2023 00:00:00
# ..                   ...
# 350  10/03/2023 00:00:00
# 351  09/08/2023 00:00:00
# 353  04/02/2023 00:00:00
# 354  28/06/2023 00:00:00
# 359  25/11/2023 00:00:00
#
# [102 rows x 5 columns]

# %%
# Rename the values in the Online or In-person field, Online of the 1 values and In-Person for the 2 values
df['Online or In-Person'] = df['Online or In-Person'].apply(lambda x: 'Online' if x==1 else 'In-Person')

# %%
# Change the date to be the quarter
df['Transaction Date'] = pd.to_datetime(df['Transaction Date'])
df['Quarter'] = df['Transaction Date'].apply(lambda x: x.quarter)
df = df.drop('Transaction Date',axis=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Transaction Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18456/3663477255.py in <module>
# ----> 1 df['Transaction Date']
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Transaction Date'

# %%
df_1 = df.drop('Customer Code',axis=1)
df_1 = df_1.groupby(by=['Quarter','Online or In-Person']).sum()
df_1 = df_1.reset_index()

# %%
# Pivot the quarterly targets so we have a row for each Type of Transaction and each Quarter and Rename the fields
targets = targets.melt(id_vars=["Online or In-Person"], 
        var_name="Quarter", 
        value_name="Quarterly Target")
# Out:
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   after removing the cwd from sys.path.

# %%
targets
# Out:
#    Online or In-Person           Quarter Quarterly Target
# 0               Online           Quarter           uarter
# 1            In-Person           Quarter           uarter
# 2               Online           Quarter           uarter
# 3            In-Person           Quarter           uarter
# 4               Online           Quarter           uarter
# 5            In-Person           Quarter           uarter
# 6               Online           Quarter           uarter
# 7            In-Person           Quarter           uarter
# 8               Online           Quarter  uarterly Target
# 9            In-Person           Quarter  uarterly Target
# 10              Online           Quarter  uarterly Target
# 11           In-Person           Quarter  uarterly Target
# 12              Online           Quarter  uarterly Target
# 13           In-Person           Quarter  uarterly Target
# 14              Online           Quarter  uarterly Target
# 15           In-Person           Quarter  uarterly Target
# 16              Online  Quarterly Target                1
# 17           In-Person  Quarterly Target                1
# 18              Online  Quarterly Target                2
# 19           In-Person  Quarterly Target                2
# 20              Online  Quarterly Target                3
# 21           In-Person  Quarterly Target                3
# 22              Online  Quarterly Target                4
# 23           In-Person  Quarterly Target                4
# 24              Online  Quarterly Target            72500
# 25           In-Person  Quarterly Target            75000
# 26              Online  Quarterly Target            70000
# 27           In-Person  Quarterly Target            70000
# 28              Online  Quarterly Target            60000
# 29           In-Person  Quarterly Target            70000
# 30              Online  Quarterly Target            60000
# 31           In-Person  Quarterly Target            60000

# %%
# Remove the 'Q' from the quarter field and make the data type numeric
targets['Quarter'] = targets['Quarter'].apply(lambda x: x.replace('Q',''))

# %%
# Join the two datasets together
df_1.join(targets, how='left', on=['Quarter', 'Online or In-Person'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18456/1195160719.py in <module>
#       1 # Join the two datasets together
# ----> 2 df_1.join(targets, how='left', on=['Quarter', 'Online or In-Person'])
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9099         """
#    9100         return self._join_compat(
# -> 9101             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9102         )
#    9103
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9137                 right_index=True,
#    9138                 suffixes=(lsuffix, rsuffix),
# -> 9139                 sort=sort,
#    9140             )
#    9141         else:
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     116         copy=copy,
#     117         indicator=indicator,
# --> 118         validate=validate,
#     119     )
#     120     return op.get_result()
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     678             warnings.warn(msg, FutureWarning, stacklevel=3)
#     679
# --> 680         self._validate_specification()
#     681
#     682         cross_col = None
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1379                 if len(self.left_on) != self.right.index.nlevels:
#    1380                     raise ValueError(
# -> 1381                         "len(left_on) must equal the number "
#    1382                         'of levels in the index of "right"'
#    1383                     )
#
# ValueError: len(left_on) must equal the number of levels in the index of "right"

# %%
df_1['Transaction Date'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Transaction Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18456/816337183.py in <module>
# ----> 1 df_1['Transaction Date'][0]
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\users\taraka pavan sriram\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Transaction Date'

# %%
df_1
# Out:
#    Quarter Online or In-Person   Value
# 0        1           In-Person  184553
# 1        1              Online  226287
# 2        2           In-Person  243330
# 3        2              Online  200131
# 4        3           In-Person  254294
# 5        3              Online  257709
# 6        4           In-Person  266570
# 7        4              Online  169793
